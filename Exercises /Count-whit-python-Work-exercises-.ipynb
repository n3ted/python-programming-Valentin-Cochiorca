# %% [markdown]
# ## 1. Pythagorean theorem (*)
#
# &nbsp; a) &nbsp;  A right angled triangle has the catheti: a = 3 and b = 4 length units. Compute the <b>hypothenuse</b> of the triangle. (*)
#
# &nbsp; b) &nbsp;  A right angled triangle has hypothenuse c = 7.0 and a cathetus a = 5.0 length units. Compute the other cathetus and round to one decimal. (*)
#
# ![right-angle-triangle.png](attachment:right-angle-triangle.png)

# %% [markdown]
#   a)

# %%
import math

# Length of the catheti
a = 3
b = 4

# Calculate the length of the hypotenuse using the Pythagorean theorem
c = math.sqrt(a**2 + b**2)

# Print the result
print(f"The length of the hypotenuse is {c} l.e")
# Out:
# The length of the hypotenuse is 5.0 l.e

# %% [markdown]
# b)

# %%
import math

# Length of the catheti a
a = 5.0
# Length of the hypothenusa
c = 7.0

# Calculate the length of the catheti b using the Pythagorean theorem
b = math.sqrt(c**2 - a**2)
rounded_b = round(b, 1)

# Print the result
print(f"The length of the chateti b is {rounded_b} l.e")
# Out:
# The length of the chateti b is 4.9 l.e

# %% [markdown]
# ---
# ## 2. Classification accuracy (*)
#
# A machine learning algorithm has been trained to predict whether or not it would rain the next day. Out of 365 predictions, it got 300 correct, compute the accuracy of this model.

# %%
# One year of predictions
days_predicted = 365

# Correct predictions
correct_predictions = 300

# Calculate accuracy as a percentage
accuracy_model = (correct_predictions / days_predicted) * 100

# Round accuracy to one decimal place
rounded_accuracy = round(accuracy_model, 1)

print(f"The accuracy of the model is {rounded_accuracy}%")
# Out:
# The accuracy of the model is 82.2%

# %% [markdown]
# ---
# ## 3. Classification accuracy (*)
# A machine learning model has been trained to detect fire. Here is the result of its predictions:
#
# <table align="left">
# <tbody>
#   <tr>
#     <td>True Positive (TP)
#       <ul>
#         <li>Reality: fire</li>
#         <li>Predicted: fire</li>
#         <li>Number of TP: 2</li>
#       </ul>
#     </td>
#     <td>False Positive (FP)
#       <ul>
#         <li>Reality: no fire</li>
#         <li>Predicted: fire</li>
#         <li>Number of FP: 2</li>
#       </ul>
#     </td>
#   </tr>
#
#   <tr>
#     <td>False Negative (FN)
#       <ul>
#         <li>Reality: fire</li>
#         <li>Predicted: no fire</li>
#         <li>Number of FN: 11</li>
#       </ul>
#     </td>
#     <td>True Negative (TN)
#       <ul>
#         <li>Reality: no fire</li>
#         <li>Predicted: no fire</li>
#         <li>Number of TN: 985</li>
#       </ul>
#     </td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# Calculated the accuracy using the following formula:
#
# $\text{accuracy} = \frac{TP+TN}{TP+TN+FP+FN}$
#
# Is this a good model?
#
#
# Try to understand what it means for the actual user with each category

# %%
# Given values
TP = 2
FP = 2
FN = 11
TN = 985

# Calculate accuracy using the provided formula
accuracy = (TP + TN) / (TP + TN + FP + FN)

# Convert accuracy to percentage
accuracy_percentage = accuracy * 100

print(f"Classification Accuracy: {accuracy_percentage:.2f}%")
# Out:
# Classification Accuracy: 98.70%

# %% [markdown]
# ---
#
# ## 4. Line (*)
# Compute the slope $k$ and the constant term $m$ of this line using the points $A: (4,4)$ and $B: (0,1)$.
#
# ![line.png](attachment:line.png)

# %% [markdown]
# Code 1:

# %%
x1 = 4
x2 = 0

y1 = 4
y2 = 1

# Solve for slope k = (y1-y2)/(x1-x2)

slope_k = (y1-y2)/(x1-x2)

# solve for m using straight line equation y = kx + m

m = y1-(slope_k*x1)
print(f"slope k is = {slope_k} and m = {m}")
# Out:
# slope k is = 0.75 and m = 1.0

# %% [markdown]
# Code 2:

# %%
# Define the points A and B as tuples (x, y)
A = (4, 4)
B = (0, 1)

# Calculate the slope (k) and constant term (m) in a single line
k, m = (A[1] - B[1]) / (A[0] - B[0]), A[1] - ((A[1] - B[1]) / (A[0] - B[0])) * A[0]

print(f"slope k is = {k} and m = {m}")
# Out:
# slope k is = 0.75 and m = 1.0

# %% [markdown]
# ---
# ## 5. Euclidean distance (*)
#
# The Euclideam distance between the points $P_1$ and $P_2$ is the length of a line between them. Let $P_1: (3,5)$ and $P_2: (-2,4)$ and compute the distance between them.

# %%
# Define the coordinates of the two points
x1, y1 = 3, 5
x2, y2 = -2, 4

# Calculate the Euclidean distance using the distance formula
distance = ((x1 - x2) ** 2 + (y1 - y2) ** 2) ** 0.5

# Round the distance to one decimal point
rounded_distance = round(distance, 1)

print(f"The Euclidean distance between P1 and P2 is {rounded_distance}")
# Out:
# The Euclidean distance between P1 and P2 is 5.1

# %% [markdown]
# ---
# ## 6. Euclidean distance in 3D (**)
#
# Calculate the distance between the points $P_1: (2,1,4)$ and $P_2: (3,1,0)$

# %%
# Define the coordinates of the two points
x1, y1, z1 = 2, 1, 4
x2, y2, z2 = 3, 1, 0

# Calculate the Euclidean distance using the 3D distance formula
distance = ((x2 - x1) ** 2 + (y2 - y1) ** 2 + (z2 - z1) ** 2) ** 0.5

# Round the distance to two decimal places
rounded_distance = round(distance, 2)

print(f"The Euclidean distance between P1 and P2 is {rounded_distance}")
# Out:
# The Euclidean distance between P1 and P2 is 4.12
